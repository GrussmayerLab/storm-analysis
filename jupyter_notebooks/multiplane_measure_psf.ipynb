# %% [markdown]
# ## Measuring PSFs for Multiplane Analysis
#
# In this example we'll measure microscope PSFs for multiplane analysis (biplane in the example).

# %% [markdown]
# ### Configuration
#
# As with Spliner, to measure the PSF you'll need a movie of sparse fluorescent beads being scanned through the microscope focus. We typically do this with small fluorescent beads on the order of 0.1um in diameter. The beads are fixed to the coverslip using a buffer with 100mM MgCl2. The coverslip is scanned through the focus in 10nm steps using a piezo z scanner. We assume that the drift in XYZ is neglible during the time it takes to take these movies (10s of seconds).
#
# In this example we're just going to simulate this using a distortion free theoritical PSF.

# %%
import os
root=r"F:\moritz\babcock_test\biplane_500nm"
script_root = r'E:\GitHub\storm-analysis\storm_analysis'
os.chdir(root)
print(os.getcwd())
# Out:
# F:\moritz\babcock_test\biplane_500nm

# %% [markdown]
# Generate the sample data for this example.
#
# Typically you will need sCMOS calibration files for your cameras as well a file containing the (first order) transform betweens the cameras.
# The `scmos_cal` notebook discusses how to calibrate a camera.
# The `micrometry_mapping` notebook discusses one approach to measuring the transform between different cameras.

# %%
#import storm_analysis.jupyter_examples.multiplane_measure_psf as multiplane_measure_psf
os.chdir(script_root)
import jupyter_examples.multiplane_measure_psf_extbiplane as multiplane_measure_psf
os.chdir(root)

# Make a fake CMOS calibration file.
multiplane_measure_psf.makeCMOSCalibration()

# Make a fake mapping file.
multiplane_measure_psf.makeMapping()

# Make a bead movie for each camera.
multiplane_measure_psf.makeSampleData()
# Out:
# Creating data for PSF measurement.
# Added 18
# Added 18
# Added 18
# Frame 0 18 emitters
# Frame 1 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 91 18 emitters
# Frame 92 18 emitters
# Frame 93 18 emitters
# Frame 94 18 emitters
# Frame 95 18 emitters
# Frame 96 18 emitters
# Frame 97 18 emitters
# Frame 98 18 emitters
# Frame 99 18 emitters
# Frame 100 18 emitters
# Frame 101 18 emitters
# Frame 102 18 emitters
# Frame 103 18 emitters
# Frame 104 18 emitters
# Frame 105 18 emitters
# Frame 106 18 emitters
# Frame 107 18 emitters
# Frame 108 18 emitters
# Frame 109 18 emitters
# Frame 110 18 emitters
# Frame 111 18 emitters
# Frame 112 18 emitters
# Frame 113 18 emitters
# Frame 114 18 emitters
# Frame 115 18 emitters
# Frame 116 18 emitters
# Frame 117 18 emitters
# Frame 118 18 emitters
# Frame 119 18 emitters
# Frame 120 18 emitters
# Frame 121 18 emitters
# Frame 122 18 emitters
# Frame 123 18 emitters
# Frame 124 18 emitters
# Frame 125 18 emitters
# Frame 126 18 emitters
# Frame 127 18 emitters
# Frame 128 18 emitters
# Frame 129 18 emitters
# Frame 130 18 emitters
# Frame 131 18 emitters
# Frame 132 18 emitters
# Frame 133 18 emitters
# Frame 134 18 emitters
# Frame 135 18 emitters
# Frame 136 18 emitters
# Frame 137 18 emitters
# Frame 138 18 emitters
# Frame 139 18 emitters
# Frame 140 18 emitters
# Frame 141 18 emitters
# Frame 142 18 emitters
# Frame 143 18 emitters
# Frame 144 18 emitters
# Frame 145 18 emitters
# Frame 146 18 emitters
# Frame 147 18 emitters
# Frame 148 18 emitters
# Frame 149 18 emitters
# Frame 150 18 emitters
# Frame 151 18 emitters
# Frame 152 18 emitters
# Frame 153 18 emitters
# Frame 154 18 emitters
# Frame 155 18 emitters
# Frame 156 18 emitters
# Frame 157 18 emitters
# Frame 158 18 emitters
# Frame 159 18 emitters
# Frame 160 18 emitters
# Frame 161 18 emitters
# Frame 162 18 emitters
# Frame 163 18 emitters
# Frame 164 18 emitters
# Frame 165 18 emitters
# Frame 166 18 emitters
# Frame 167 18 emitters
# Frame 168 18 emitters
# Frame 169 18 emitters
# Frame 170 18 emitters
# Frame 171 18 emitters
# Frame 172 18 emitters
# Frame 173 18 emitters
# Frame 174 18 emitters
# Frame 175 18 emitters
# Frame 176 18 emitters
# Frame 177 18 emitters
# Frame 178 18 emitters
# Frame 179 18 emitters
# Frame 180 18 emitters
# Frame 181 18 emitters
# Frame 182 18 emitters
# Frame 183 18 emitters
# Frame 184 18 emitters
# Frame 185 18 emitters
# Frame 186 18 emitters
# Frame 187 18 emitters
# Frame 188 18 emitters
# Frame 189 18 emitters
# Frame 190 18 emitters
# Frame 191 18 emitters
# Frame 192 18 emitters
# Frame 193 18 emitters
# Frame 194 18 emitters
# Frame 195 18 emitters
# Frame 196 18 emitters
# Frame 197 18 emitters
# Frame 198 18 emitters
# Frame 199 18 emitters
# Frame 200 18 emitters
# Frame 0 18 emitters
# Frame 1 18 emitters
# Frame 2 18 emitters
# Frame 3 18 emitters
# Frame 4 18 emitters
# Frame 5 18 emitters
# Frame 6 18 emitters
# Frame 7 18 emitters
# Frame 8 18 emitters
# Frame 9 18 emitters
# Frame 10 18 emitters
# Frame 11 18 emitters
# Frame 12 18 emitters
# Frame 13 18 emitters
# Frame 14 18 emitters
# Frame 15 18 emitters
# Frame 16 18 emitters
# Frame 17 18 emitters
# Frame 18 18 emitters
# Frame 19 18 emitters
# Frame 20 18 emitters
# Frame 21 18 emitters
# Frame 22 18 emitters
# Frame 23 18 emitters
# Frame 24 18 emitters
# Frame 25 18 emitters
# Frame 26 18 emitters
# Frame 27 18 emitters
# Frame 28 18 emitters
# Frame 29 18 emitters
# Frame 30 18 emitters
# Frame 31 18 emitters
# Frame 32 18 emitters
# Frame 33 18 emitters
# Frame 34 18 emitters
# Frame 35 18 emitters
# Frame 36 18 emitters
# Frame 37 18 emitters
# Frame 38 18 emitters
# Frame 39 18 emitters
# Frame 40 18 emitters
# Frame 41 18 emitters
# Frame 42 18 emitters
# Frame 43 18 emitters
# Frame 44 18 emitters
# Frame 45 18 emitters
# Frame 46 18 emitters
# Frame 47 18 emitters
# Frame 48 18 emitters
# Frame 49 18 emitters
# Frame 50 18 emitters
# Frame 51 18 emitters
# Frame 52 18 emitters
# Frame 53 18 emitters
# Frame 54 18 emitters
# Frame 55 18 emitters
# Frame 56 18 emitters
# Frame 57 18 emitters
# Frame 58 18 emitters
# Frame 59 18 emitters
# Frame 60 18 emitters
# Frame 61 18 emitters
# Frame 62 18 emitters
# Frame 63 18 emitters
# Frame 64 18 emitters
# Frame 65 18 emitters
# Frame 66 18 emitters
# Frame 67 18 emitters
# Frame 68 18 emitters
# Frame 69 18 emitters
# Frame 70 18 emitters
# Frame 71 18 emitters
# Frame 72 18 emitters
# Frame 73 18 emitters
# Frame 74 18 emitters
# Frame 75 18 emitters
# Frame 76 18 emitters
# Frame 77 18 emitters
# Frame 78 18 emitters
# Frame 79 18 emitters
# Frame 80 18 emitters
# Frame 81 18 emitters
# Frame 82 18 emitters
# Frame 83 18 emitters
# Frame 84 18 emitters
# Frame 85 18 emitters
# Frame 86 18 emitters
# Frame 87 18 emitters
# Frame 88 18 emitters
# Frame 89 18 emitters
# Frame 90 18 emitters
# Frame 91 18 emitters
# Frame 92 18 emitters
# Frame 93 18 emitters
# Frame 94 18 emitters
# Frame 95 18 emitters
# Frame 96 18 emitters
# Frame 97 18 emitters
# Frame 98 18 emitters
# Frame 99 18 emitters
# Frame 100 18 emitters
# Frame 101 18 emitters
# Frame 102 18 emitters
# Frame 103 18 emitters
# Frame 104 18 emitters
# Frame 105 18 emitters
# Frame 106 18 emitters
# Frame 107 18 emitters
# Frame 108 18 emitters
# Frame 109 18 emitters
# Frame 110 18 emitters
# Frame 111 18 emitters
# Frame 112 18 emitters
# Frame 113 18 emitters
# Frame 114 18 emitters
# Frame 115 18 emitters
# Frame 116 18 emitters
# Frame 117 18 emitters
# Frame 118 18 emitters
# Frame 119 18 emitters
# Frame 120 18 emitters
# Frame 121 18 emitters
# Frame 122 18 emitters
# Frame 123 18 emitters
# Frame 124 18 emitters
# Frame 125 18 emitters
# Frame 126 18 emitters
# Frame 127 18 emitters
# Frame 128 18 emitters
# Frame 129 18 emitters
# Frame 130 18 emitters
# Frame 131 18 emitters
# Frame 132 18 emitters
# Frame 133 18 emitters
# Frame 134 18 emitters
# Frame 135 18 emitters
# Frame 136 18 emitters
# Frame 137 18 emitters
# Frame 138 18 emitters
# Frame 139 18 emitters
# Frame 140 18 emitters
# Frame 141 18 emitters
# Frame 142 18 emitters
# Frame 143 18 emitters
# Frame 144 18 emitters
# Frame 145 18 emitters
# Frame 146 18 emitters
# Frame 147 18 emitters
# Frame 148 18 emitters
# Frame 149 18 emitters
# Frame 150 18 emitters
# Frame 151 18 emitters
# Frame 152 18 emitters
# Frame 153 18 emitters
# Frame 154 18 emitters
# Frame 155 18 emitters
# Frame 156 18 emitters
# Frame 157 18 emitters
# Frame 158 18 emitters
# Frame 159 18 emitters
# Frame 160 18 emitters
# Frame 161 18 emitters
# Frame 162 18 emitters
# Frame 163 18 emitters
# Frame 164 18 emitters
# Frame 165 18 emitters
# Frame 166 18 emitters
# Frame 167 18 emitters
# Frame 168 18 emitters
# Frame 169 18 emitters
# Frame 170 18 emitters
# Frame 171 18 emitters
# Frame 172 18 emitters
# Frame 173 18 emitters
# Frame 174 18 emitters
# Frame 175 18 emitters
# Frame 176 18 emitters
# Frame 177 18 emitters
# Frame 178 18 emitters
# Frame 179 18 emitters
# Frame 180 18 emitters
# Frame 181 18 emitters
# Frame 182 18 emitters
# Frame 183 18 emitters
# Frame 184 18 emitters
# Frame 185 18 emitters
# Frame 186 18 emitters
# Frame 187 18 emitters
# Frame 188 18 emitters
# Frame 189 18 emitters
# Frame 190 18 emitters
# Frame 191 18 emitters
# Frame 192 18 emitters
# Frame 193 18 emitters
# Frame 194 18 emitters
# Frame 195 18 emitters
# Frame 196 18 emitters
# Frame 197 18 emitters
# Frame 198 18 emitters
# Frame 199 18 emitters
# Frame 200 18 emitters

# %% [markdown]
# ### Identifying localizations to use in the PSF measurement.
#
# The first step is to identify the localizations to use for PSF measurement. This is done by first analyzing an in focus image in channel 0 (the reference channel) with sCMOS (or 3D-DAOSTORM). Then the `psfLocalizations()` function is used to select localizations that are isolated from each other and also inside all of the images from all of the cameras.

# %%
# Identify localizations using sCMOS.

# This will create an analysis XML file that we can use for sCMOS analysis.
multiplane_measure_psf.sCMOSSingleFrameXML()

# Remove stale results, if any.
if os.path.exists("c1_zcal.hdf5"):
    os.remove("c1_zcal.hdf5")
    
# Run sCMOS analysis.
import storm_analysis.sCMOS.scmos_analysis as scmosAnalysis
scmosAnalysis.analyze("c1_zcal.dax", "c1_zcal.hdf5", "scmos_single_plane.xml")

# Select good localizations in one of the analyzed frames (frame 100 in this example)
# We specify a minimum localization separation of 28 pixels (2 x aoi_size).
import storm_analysis.multi_plane.psf_localizations as psfLocalizations
#psfLocalizations.psfLocalizations("c1_zcal.hdf5", "map.map", frame = 100, aoi_size = 14)
psfLocalizations.psfLocalizations("c1_zcal.hdf5", "map.map", frame =150, aoi_size = 14)
# Out:
# version 2023.02.26
#
# Peak finding
#  Removing values < 1.0 in frame 0
# Frame: 0 0 0
#  Removing values < 1.0 in frame 1
# Frame: 1 0 0
#  Removing values < 1.0 in frame 2
# Frame: 2 0 0
#  Removing values < 1.0 in frame 3
# Frame: 3 0 0
#  Removing values < 1.0 in frame 4
# Frame: 4 0 0
#  Removing values < 1.0 in frame 5
# Frame: 5 0 0
#  Removing values < 1.0 in frame 6
# Frame: 6 0 0
#  Removing values < 1.0 in frame 7
# Frame: 7 0 0
#  Removing values < 1.0 in frame 8
# Frame: 8 0 0
#  Removing values < 1.0 in frame 9
# Frame: 9 0 0
#  Removing values < 1.0 in frame 10
# Frame: 10 0 0
#  Removing values < 1.0 in frame 11
# Frame: 11 0 0
#  Removing values < 1.0 in frame 12
# Frame: 12 0 0
#  Removing values < 1.0 in frame 13
# Frame: 13 0 0
#  Removing values < 1.0 in frame 14
# Frame: 14 0 0
#  Removing values < 1.0 in frame 15
# Frame: 15 0 0
#  Removing values < 1.0 in frame 16
# Frame: 16 0 0
#  Removing values < 1.0 in frame 17
# Frame: 17 0 0
#  Removing values < 1.0 in frame 18
# Frame: 18 0 0
#  Removing values < 1.0 in frame 19
# Frame: 19 0 0
#  Removing values < 1.0 in frame 20
# Frame: 20 0 0
#  Removing values < 1.0 in frame 21
# Frame: 21 0 0
#  Removing values < 1.0 in frame 22
# Frame: 22 0 0
#  Removing values < 1.0 in frame 23
# Frame: 23 0 0
#  Removing values < 1.0 in frame 24
# Frame: 24 0 0
#  Removing values < 1.0 in frame 25
# Frame: 25 0 0
#  Removing values < 1.0 in frame 26
# Frame: 26 0 0
#  Removing values < 1.0 in frame 27
# Frame: 27 0 0
#  Removing values < 1.0 in frame 28
# Frame: 28 0 0
#  Removing values < 1.0 in frame 29
# Frame: 29 0 0
#  Removing values < 1.0 in frame 30
# Frame: 30 0 0
#  Removing values < 1.0 in frame 31
# Frame: 31 0 0
#  Removing values < 1.0 in frame 32
# Frame: 32 0 0
#  Removing values < 1.0 in frame 33
# Frame: 33 0 0
#  Removing values < 1.0 in frame 34
# Frame: 34 0 0
#  Removing values < 1.0 in frame 35
# Frame: 35 0 0
#  Removing values < 1.0 in frame 36
# Frame: 36 0 0
#  Removing values < 1.0 in frame 37
# Frame: 37 0 0
#  Removing values < 1.0 in frame 38
# Frame: 38 0 0
#  Removing values < 1.0 in frame 39
# Frame: 39 0 0
#  Removing values < 1.0 in frame 40
# Frame: 40 0 0
#  Removing values < 1.0 in frame 41
# Frame: 41 0 0
#  Removing values < 1.0 in frame 42
# Frame: 42 0 0
#  Removing values < 1.0 in frame 43
# Frame: 43 0 0
#  Removing values < 1.0 in frame 44
# Frame: 44 0 0
#  Removing values < 1.0 in frame 45
# Frame: 45 0 0
#  Removing values < 1.0 in frame 46
# Frame: 46 0 0
#  Removing values < 1.0 in frame 47
# Frame: 47 0 0
#  Removing values < 1.0 in frame 48
# Frame: 48 0 0
#  Removing values < 1.0 in frame 49
# Frame: 49 0 0
#  Removing values < 1.0 in frame 50
# Frame: 50 0 0
#  Removing values < 1.0 in frame 51
# Frame: 51 0 0
#  Removing values < 1.0 in frame 52
# Frame: 52 0 0
#  Removing values < 1.0 in frame 53
# Frame: 53 0 0
#  Removing values < 1.0 in frame 54
# Frame: 54 0 0
#  Removing values < 1.0 in frame 55
# Frame: 55 0 0
#  Removing values < 1.0 in frame 56
# Frame: 56 0 0
#  Removing values < 1.0 in frame 57
# Frame: 57 0 0
#  Removing values < 1.0 in frame 58
# Frame: 58 0 0
#  Removing values < 1.0 in frame 59
# Frame: 59 0 0
#  Removing values < 1.0 in frame 60
# Frame: 60 0 0
#  Removing values < 1.0 in frame 61
# Frame: 61 0 0
#  Removing values < 1.0 in frame 62
# Frame: 62 0 0
#  Removing values < 1.0 in frame 63
# Frame: 63 0 0
#  Removing values < 1.0 in frame 64
# Frame: 64 0 0
#  Removing values < 1.0 in frame 65
# Frame: 65 0 0
#  Removing values < 1.0 in frame 66
# Frame: 66 0 0
#  Removing values < 1.0 in frame 67
# Frame: 67 0 0
#  Removing values < 1.0 in frame 68
# Frame: 68 0 0
#  Removing values < 1.0 in frame 69
# Frame: 69 0 0
#  Removing values < 1.0 in frame 70
# Frame: 70 0 0
#  Removing values < 1.0 in frame 71
# Frame: 71 0 0
#  Removing values < 1.0 in frame 72
# Frame: 72 0 0
#  Removing values < 1.0 in frame 73
# Frame: 73 0 0
#  Removing values < 1.0 in frame 74
# Frame: 74 0 0
#  Removing values < 1.0 in frame 75
# Frame: 75 0 0
#  Removing values < 1.0 in frame 76
# Frame: 76 0 0
#  Removing values < 1.0 in frame 77
# Frame: 77 0 0
#  Removing values < 1.0 in frame 78
# Frame: 78 0 0
#  Removing values < 1.0 in frame 79
# Frame: 79 1 1
#  Removing values < 1.0 in frame 80
# Frame: 80 16 17
#  Removing values < 1.0 in frame 81
# Frame: 81 18 35
#  Removing values < 1.0 in frame 82
# Frame: 82 18 53
#  Removing values < 1.0 in frame 83
# Frame: 83 18 71
#  Removing values < 1.0 in frame 84
# Frame: 84 18 89
#  Removing values < 1.0 in frame 85
# Frame: 85 18 107
#  Removing values < 1.0 in frame 86
# Frame: 86 18 125
#  Removing values < 1.0 in frame 87
# Frame: 87 18 143
#  Removing values < 1.0 in frame 88
# Frame: 88 18 161
#  Removing values < 1.0 in frame 89
# Frame: 89 18 179
#  Removing values < 1.0 in frame 90
# Frame: 90 18 197
#  Removing values < 1.0 in frame 91
# Frame: 91 18 215
#  Removing values < 1.0 in frame 92
# Frame: 92 18 233
#  Removing values < 1.0 in frame 93
# Frame: 93 18 251
#  Removing values < 1.0 in frame 94
# Frame: 94 18 269
#  Removing values < 1.0 in frame 95
# Frame: 95 18 287
#  Removing values < 1.0 in frame 96
# Frame: 96 18 305
#  Removing values < 1.0 in frame 97
# Frame: 97 18 323
#  Removing values < 1.0 in frame 98
# Frame: 98 18 341
#  Removing values < 1.0 in frame 99
# Frame: 99 18 359
#  Removing values < 1.0 in frame 100
# Frame: 100 18 377
#  Removing values < 1.0 in frame 101
# Frame: 101 18 395
#  Removing values < 1.0 in frame 102
# Frame: 102 18 413
#  Removing values < 1.0 in frame 103
# Frame: 103 18 431
#  Removing values < 1.0 in frame 104
# Frame: 104 18 449
#  Removing values < 1.0 in frame 105
# Frame: 105 18 467
#  Removing values < 1.0 in frame 106
# Frame: 106 18 485
#  Removing values < 1.0 in frame 107
# Frame: 107 18 503
#  Removing values < 1.0 in frame 108
# Frame: 108 18 521
#  Removing values < 1.0 in frame 109
# Frame: 109 18 539
#  Removing values < 1.0 in frame 110
# Frame: 110 18 557
#  Removing values < 1.0 in frame 111
# Frame: 111 18 575
#  Removing values < 1.0 in frame 112
# Frame: 112 18 593
#  Removing values < 1.0 in frame 113
# Frame: 113 18 611
#  Removing values < 1.0 in frame 114
# Frame: 114 18 629
#  Removing values < 1.0 in frame 115
# Frame: 115 18 647
#  Removing values < 1.0 in frame 116
# Frame: 116 18 665
#  Removing values < 1.0 in frame 117
# Frame: 117 18 683
#  Removing values < 1.0 in frame 118
# Frame: 118 18 701
#  Removing values < 1.0 in frame 119
# Frame: 119 18 719
#  Removing values < 1.0 in frame 120
# Frame: 120 18 737
#  Removing values < 1.0 in frame 121
# Frame: 121 18 755
#  Removing values < 1.0 in frame 122
# Frame: 122 18 773
#  Removing values < 1.0 in frame 123
# Frame: 123 18 791
#  Removing values < 1.0 in frame 124
# Frame: 124 18 809
#  Removing values < 1.0 in frame 125
# Frame: 125 18 827
#  Removing values < 1.0 in frame 126
# Frame: 126 18 845
#  Removing values < 1.0 in frame 127
# Frame: 127 18 863
#  Removing values < 1.0 in frame 128
# Frame: 128 18 881
#  Removing values < 1.0 in frame 129
# Frame: 129 18 899
#  Removing values < 1.0 in frame 130
# Frame: 130 18 917
#  Removing values < 1.0 in frame 131
# Frame: 131 18 935
#  Removing values < 1.0 in frame 132
# Frame: 132 18 953
#  Removing values < 1.0 in frame 133
# Frame: 133 18 971
#  Removing values < 1.0 in frame 134
# Frame: 134 18 989
#  Removing values < 1.0 in frame 135
# Frame: 135 18 1007
#  Removing values < 1.0 in frame 136
# Frame: 136 18 1025
#  Removing values < 1.0 in frame 137
# Frame: 137 18 1043
#  Removing values < 1.0 in frame 138
# Frame: 138 18 1061
#  Removing values < 1.0 in frame 139
# Frame: 139 18 1079
#  Removing values < 1.0 in frame 140
# Frame: 140 18 1097
#  Removing values < 1.0 in frame 141
# Frame: 141 18 1115
#  Removing values < 1.0 in frame 142
# Frame: 142 18 1133
#  Removing values < 1.0 in frame 143
# Frame: 143 18 1151
#  Removing values < 1.0 in frame 144
# Frame: 144 18 1169
#  Removing values < 1.0 in frame 145
# Frame: 145 18 1187
#  Removing values < 1.0 in frame 146
# Frame: 146 18 1205
#  Removing values < 1.0 in frame 147
# Frame: 147 18 1223
#  Removing values < 1.0 in frame 148
# Frame: 148 18 1241
#  Removing values < 1.0 in frame 149
# Frame: 149 18 1259
#  Removing values < 1.0 in frame 150
# Frame: 150 18 1277
#  Removing values < 1.0 in frame 151
# Frame: 151 18 1295
#  Removing values < 1.0 in frame 152
# Frame: 152 18 1313
#  Removing values < 1.0 in frame 153
# Frame: 153 18 1331
#  Removing values < 1.0 in frame 154
# Frame: 154 18 1349
#  Removing values < 1.0 in frame 155
# Frame: 155 18 1367
#  Removing values < 1.0 in frame 156
# Frame: 156 18 1385
#  Removing values < 1.0 in frame 157
# Frame: 157 18 1403
#  Removing values < 1.0 in frame 158
# Frame: 158 18 1421
#  Removing values < 1.0 in frame 159
# Frame: 159 18 1439
#  Removing values < 1.0 in frame 160
# Frame: 160 18 1457
#  Removing values < 1.0 in frame 161
# Frame: 161 18 1475
#  Removing values < 1.0 in frame 162
# Frame: 162 18 1493
#  Removing values < 1.0 in frame 163
# Frame: 163 18 1511
#  Removing values < 1.0 in frame 164
# Frame: 164 18 1529
#  Removing values < 1.0 in frame 165
# Frame: 165 18 1547
#  Removing values < 1.0 in frame 166
# Frame: 166 18 1565
#  Removing values < 1.0 in frame 167
# Frame: 167 18 1583
#  Removing values < 1.0 in frame 168
# Frame: 168 18 1601
#  Removing values < 1.0 in frame 169
# Frame: 169 18 1619
#  Removing values < 1.0 in frame 170
# Frame: 170 18 1637
#  Removing values < 1.0 in frame 171
# Frame: 171 2 1639
#  Removing values < 1.0 in frame 172
# Frame: 172 0 1639
#  Removing values < 1.0 in frame 173
# Frame: 173 0 1639
#  Removing values < 1.0 in frame 174
# Frame: 174 0 1639
#  Removing values < 1.0 in frame 175
# Frame: 175 0 1639
#  Removing values < 1.0 in frame 176
# Frame: 176 0 1639
#  Removing values < 1.0 in frame 177
# Frame: 177 0 1639
#  Removing values < 1.0 in frame 178
# Frame: 178 0 1639
#  Removing values < 1.0 in frame 179
# Frame: 179 0 1639
#  Removing values < 1.0 in frame 180
# Frame: 180 0 1639
#  Removing values < 1.0 in frame 181
# Frame: 181 0 1639
#  Removing values < 1.0 in frame 182
# Frame: 182 0 1639
#  Removing values < 1.0 in frame 183
# Frame: 183 0 1639
#  Removing values < 1.0 in frame 184
# Frame: 184 0 1639
#  Removing values < 1.0 in frame 185
# Frame: 185 0 1639
#  Removing values < 1.0 in frame 186
# Frame: 186 0 1639
#  Removing values < 1.0 in frame 187
# Frame: 187 0 1639
#  Removing values < 1.0 in frame 188
# Frame: 188 0 1639
#  Removing values < 1.0 in frame 189
# Frame: 189 0 1639
#  Removing values < 1.0 in frame 190
# Frame: 190 0 1639
#  Removing values < 1.0 in frame 191
# Frame: 191 0 1639
#  Removing values < 1.0 in frame 192
# Frame: 192 0 1639
#  Removing values < 1.0 in frame 193
# Frame: 193 0 1639
#  Removing values < 1.0 in frame 194
# Frame: 194 0 1639
#  Removing values < 1.0 in frame 195
# Frame: 195 0 1639
#  Removing values < 1.0 in frame 196
# Frame: 196 0 1639
#  Removing values < 1.0 in frame 197
# Frame: 197 0 1639
#  Removing values < 1.0 in frame 198
# Frame: 198 0 1639
#  Removing values < 1.0 in frame 199
# Frame: 199 0 1639
#  Removing values < 1.0 in frame 200
# Frame: 200 0 1639
#
# Added 1639
#    201 peak finding iterations.
#
#    0 fits reset due to Cholesky failure.
#    0 fits reset due to image margin.
#    0 fits reset due to negative value in fit function.
#    0 fits reset due to negative height.
#    1897 fits reset due to non-decreasing error (LM).
#    0 fits did not converge.
#    0 fits were lost.
#    0 peaks lost to proximity filter.
#    1123 peaks lost to low significance.
#    32374 fitting iterations.
#
# Tracking.
#
# Checking z values.
#
# Analysis complete
# Added 18
# Added 18
# 18 localizations were kept out of 18
# ch0: 40.34 40.30
# ch1: 42.34 45.30
#
# ch0: 80.30 39.79
# ch1: 82.30 44.79
#
# ch0: 119.83 40.28
# ch1: 121.83 45.28
#
# ch0: 160.29 40.40
# ch1: 162.29 45.40
#
# ch0: 199.98 39.60
# ch1: 201.98 44.60
#
# ch0: 239.98 40.38
# ch1: 241.98 45.38
#
# ch0: 39.97 79.72
# ch1: 41.97 84.72
#
# ch0: 79.94 80.07
# ch1: 81.94 85.07
#
# ch0: 120.13 79.73
# ch1: 122.13 84.73
#
# ch0: 159.81 80.26
# ch1: 161.81 85.26
#
# ch0: 199.93 80.10
# ch1: 201.93 85.10
#
# ch0: 239.73 80.29
# ch1: 241.73 85.29
#
# ch0: 240.06 119.50
# ch1: 242.06 124.50
#
# ch0: 40.03 119.89
# ch1: 42.03 124.89
#
# ch0: 80.42 120.04
# ch1: 82.42 125.04
#
# ch0: 120.40 120.48
# ch1: 122.40 125.48
#
# ch0: 160.39 120.16
# ch1: 162.39 125.16
#
# ch0: 200.41 120.49
# ch1: 202.41 125.49

# %%
# Visual check of the selected localizations.
print("Channel 1 (frame 150)")
multiplane_measure_psf.overlayImage("c1_zcal.dax", "c1_zcal_c1_psf.hdf5",150)

print("Channel 2 (frame 50)")
multiplane_measure_psf.overlayImage("c2_zcal.dax", "c1_zcal_c2_psf.hdf5", 50)
# Out:
# Channel 1 (frame 150)
# Channel 2 (frame 50)

# %% [markdown]
# ### Measure Z stacks for each channel.

# %%
import storm_analysis.multi_plane.psf_zstack as psfZStack

psfZStack.psfZStack("c1_zcal.dax", "c1_zcal_c1_psf.hdf5", "c1_zstack", scmos_cal = "calib.npy", aoi_size = 12)
psfZStack.psfZStack("c2_zcal.dax", "c1_zcal_c2_psf.hdf5", "c2_zstack", scmos_cal = "calib.npy", aoi_size = 12)
# Out:
# Processing frame 0
#  Removing values < 1.0 in frame 0
#  Removing values < 1.0 in frame 1
#  Removing values < 1.0 in frame 2
#  Removing values < 1.0 in frame 3
#  Removing values < 1.0 in frame 4
#  Removing values < 1.0 in frame 5
#  Removing values < 1.0 in frame 6
#  Removing values < 1.0 in frame 7
#  Removing values < 1.0 in frame 8
#  Removing values < 1.0 in frame 9
#  Removing values < 1.0 in frame 10
#  Removing values < 1.0 in frame 11
#  Removing values < 1.0 in frame 12
#  Removing values < 1.0 in frame 13
#  Removing values < 1.0 in frame 14
#  Removing values < 1.0 in frame 15
#  Removing values < 1.0 in frame 16
#  Removing values < 1.0 in frame 17
#  Removing values < 1.0 in frame 18
#  Removing values < 1.0 in frame 19
#  Removing values < 1.0 in frame 20
#  Removing values < 1.0 in frame 21
#  Removing values < 1.0 in frame 22
#  Removing values < 1.0 in frame 23
#  Removing values < 1.0 in frame 24
#  Removing values < 1.0 in frame 25
#  Removing values < 1.0 in frame 26
#  Removing values < 1.0 in frame 27
#  Removing values < 1.0 in frame 28
#  Removing values < 1.0 in frame 29
#  Removing values < 1.0 in frame 30
#  Removing values < 1.0 in frame 31
#  Removing values < 1.0 in frame 32
#  Removing values < 1.0 in frame 33
#  Removing values < 1.0 in frame 34
#  Removing values < 1.0 in frame 35
#  Removing values < 1.0 in frame 36
#  Removing values < 1.0 in frame 37
#  Removing values < 1.0 in frame 38
#  Removing values < 1.0 in frame 39
#  Removing values < 1.0 in frame 40
#  Removing values < 1.0 in frame 41
#  Removing values < 1.0 in frame 42
#  Removing values < 1.0 in frame 43
#  Removing values < 1.0 in frame 44
#  Removing values < 1.0 in frame 45
#  Removing values < 1.0 in frame 46
#  Removing values < 1.0 in frame 47
#  Removing values < 1.0 in frame 48
#  Removing values < 1.0 in frame 49
# Processing frame 50
#  Removing values < 1.0 in frame 50
#  Removing values < 1.0 in frame 51
#  Removing values < 1.0 in frame 52
#  Removing values < 1.0 in frame 53
#  Removing values < 1.0 in frame 54
#  Removing values < 1.0 in frame 55
#  Removing values < 1.0 in frame 56
#  Removing values < 1.0 in frame 57
#  Removing values < 1.0 in frame 58
#  Removing values < 1.0 in frame 59
#  Removing values < 1.0 in frame 60
#  Removing values < 1.0 in frame 61
#  Removing values < 1.0 in frame 62
#  Removing values < 1.0 in frame 63
#  Removing values < 1.0 in frame 64
#  Removing values < 1.0 in frame 65
#  Removing values < 1.0 in frame 66
#  Removing values < 1.0 in frame 67
#  Removing values < 1.0 in frame 68
#  Removing values < 1.0 in frame 69
#  Removing values < 1.0 in frame 70
#  Removing values < 1.0 in frame 71
#  Removing values < 1.0 in frame 72
#  Removing values < 1.0 in frame 73
#  Removing values < 1.0 in frame 74
#  Removing values < 1.0 in frame 75
#  Removing values < 1.0 in frame 76
#  Removing values < 1.0 in frame 77
#  Removing values < 1.0 in frame 78
#  Removing values < 1.0 in frame 79
#  Removing values < 1.0 in frame 80
#  Removing values < 1.0 in frame 81
#  Removing values < 1.0 in frame 82
#  Removing values < 1.0 in frame 83
#  Removing values < 1.0 in frame 84
#  Removing values < 1.0 in frame 85
#  Removing values < 1.0 in frame 86
#  Removing values < 1.0 in frame 87
#  Removing values < 1.0 in frame 88
#  Removing values < 1.0 in frame 89
#  Removing values < 1.0 in frame 90
#  Removing values < 1.0 in frame 91
#  Removing values < 1.0 in frame 92
#  Removing values < 1.0 in frame 93
#  Removing values < 1.0 in frame 94
#  Removing values < 1.0 in frame 95
#  Removing values < 1.0 in frame 96
#  Removing values < 1.0 in frame 97
#  Removing values < 1.0 in frame 98
#  Removing values < 1.0 in frame 99
# Processing frame 100
#  Removing values < 1.0 in frame 100
#  Removing values < 1.0 in frame 101
#  Removing values < 1.0 in frame 102
#  Removing values < 1.0 in frame 103
#  Removing values < 1.0 in frame 104
#  Removing values < 1.0 in frame 105
#  Removing values < 1.0 in frame 106
#  Removing values < 1.0 in frame 107
#  Removing values < 1.0 in frame 108
#  Removing values < 1.0 in frame 109
#  Removing values < 1.0 in frame 110
#  Removing values < 1.0 in frame 111
#  Removing values < 1.0 in frame 112
#  Removing values < 1.0 in frame 113
#  Removing values < 1.0 in frame 114
#  Removing values < 1.0 in frame 115
#  Removing values < 1.0 in frame 116
#  Removing values < 1.0 in frame 117
#  Removing values < 1.0 in frame 118
#  Removing values < 1.0 in frame 119
#  Removing values < 1.0 in frame 120
#  Removing values < 1.0 in frame 121
#  Removing values < 1.0 in frame 122
#  Removing values < 1.0 in frame 123
#  Removing values < 1.0 in frame 124
#  Removing values < 1.0 in frame 125
#  Removing values < 1.0 in frame 126
#  Removing values < 1.0 in frame 127
#  Removing values < 1.0 in frame 128
#  Removing values < 1.0 in frame 129
#  Removing values < 1.0 in frame 130
#  Removing values < 1.0 in frame 131
#  Removing values < 1.0 in frame 132
#  Removing values < 1.0 in frame 133
#  Removing values < 1.0 in frame 134
#  Removing values < 1.0 in frame 135
#  Removing values < 1.0 in frame 136
#  Removing values < 1.0 in frame 137
#  Removing values < 1.0 in frame 138
#  Removing values < 1.0 in frame 139
#  Removing values < 1.0 in frame 140
#  Removing values < 1.0 in frame 141
#  Removing values < 1.0 in frame 142
#  Removing values < 1.0 in frame 143
#  Removing values < 1.0 in frame 144
#  Removing values < 1.0 in frame 145
#  Removing values < 1.0 in frame 146
#  Removing values < 1.0 in frame 147
#  Removing values < 1.0 in frame 148
#  Removing values < 1.0 in frame 149
# Processing frame 150
#  Removing values < 1.0 in frame 150
#  Removing values < 1.0 in frame 151
#  Removing values < 1.0 in frame 152
#  Removing values < 1.0 in frame 153
#  Removing values < 1.0 in frame 154
#  Removing values < 1.0 in frame 155
#  Removing values < 1.0 in frame 156
#  Removing values < 1.0 in frame 157
#  Removing values < 1.0 in frame 158
#  Removing values < 1.0 in frame 159
#  Removing values < 1.0 in frame 160
#  Removing values < 1.0 in frame 161
#  Removing values < 1.0 in frame 162
#  Removing values < 1.0 in frame 163
#  Removing values < 1.0 in frame 164
#  Removing values < 1.0 in frame 165
#  Removing values < 1.0 in frame 166
#  Removing values < 1.0 in frame 167
#  Removing values < 1.0 in frame 168
#  Removing values < 1.0 in frame 169
#  Removing values < 1.0 in frame 170
#  Removing values < 1.0 in frame 171
#  Removing values < 1.0 in frame 172
#  Removing values < 1.0 in frame 173
#  Removing values < 1.0 in frame 174
#  Removing values < 1.0 in frame 175
#  Removing values < 1.0 in frame 176
#  Removing values < 1.0 in frame 177
#  Removing values < 1.0 in frame 178
#  Removing values < 1.0 in frame 179
#  Removing values < 1.0 in frame 180
#  Removing values < 1.0 in frame 181
#  Removing values < 1.0 in frame 182
#  Removing values < 1.0 in frame 183
#  Removing values < 1.0 in frame 184
#  Removing values < 1.0 in frame 185
#  Removing values < 1.0 in frame 186
#  Removing values < 1.0 in frame 187
#  Removing values < 1.0 in frame 188
#  Removing values < 1.0 in frame 189
#  Removing values < 1.0 in frame 190
#  Removing values < 1.0 in frame 191
#  Removing values < 1.0 in frame 192
#  Removing values < 1.0 in frame 193
#  Removing values < 1.0 in frame 194
#  Removing values < 1.0 in frame 195
#  Removing values < 1.0 in frame 196
#  Removing values < 1.0 in frame 197
#  Removing values < 1.0 in frame 198
#  Removing values < 1.0 in frame 199
# Processing frame 200
#  Removing values < 1.0 in frame 200
# Processing frame 0
#  Removing values < 1.0 in frame 0
#  Removing values < 1.0 in frame 1
#  Removing values < 1.0 in frame 2
#  Removing values < 1.0 in frame 3
#  Removing values < 1.0 in frame 4
#  Removing values < 1.0 in frame 5
#  Removing values < 1.0 in frame 6
#  Removing values < 1.0 in frame 7
#  Removing values < 1.0 in frame 8
#  Removing values < 1.0 in frame 9
#  Removing values < 1.0 in frame 10
#  Removing values < 1.0 in frame 11
#  Removing values < 1.0 in frame 12
#  Removing values < 1.0 in frame 13
#  Removing values < 1.0 in frame 14
#  Removing values < 1.0 in frame 15
#  Removing values < 1.0 in frame 16
#  Removing values < 1.0 in frame 17
#  Removing values < 1.0 in frame 18
#  Removing values < 1.0 in frame 19
#  Removing values < 1.0 in frame 20
#  Removing values < 1.0 in frame 21
#  Removing values < 1.0 in frame 22
#  Removing values < 1.0 in frame 23
#  Removing values < 1.0 in frame 24
#  Removing values < 1.0 in frame 25
#  Removing values < 1.0 in frame 26
#  Removing values < 1.0 in frame 27
#  Removing values < 1.0 in frame 28
#  Removing values < 1.0 in frame 29
#  Removing values < 1.0 in frame 30
#  Removing values < 1.0 in frame 31
#  Removing values < 1.0 in frame 32
#  Removing values < 1.0 in frame 33
#  Removing values < 1.0 in frame 34
#  Removing values < 1.0 in frame 35
#  Removing values < 1.0 in frame 36
#  Removing values < 1.0 in frame 37
#  Removing values < 1.0 in frame 38
#  Removing values < 1.0 in frame 39
#  Removing values < 1.0 in frame 40
#  Removing values < 1.0 in frame 41
#  Removing values < 1.0 in frame 42
#  Removing values < 1.0 in frame 43
#  Removing values < 1.0 in frame 44
#  Removing values < 1.0 in frame 45
#  Removing values < 1.0 in frame 46
#  Removing values < 1.0 in frame 47
#  Removing values < 1.0 in frame 48
#  Removing values < 1.0 in frame 49
# Processing frame 50
#  Removing values < 1.0 in frame 50
#  Removing values < 1.0 in frame 51
#  Removing values < 1.0 in frame 52
#  Removing values < 1.0 in frame 53
#  Removing values < 1.0 in frame 54
#  Removing values < 1.0 in frame 55
#  Removing values < 1.0 in frame 56
#  Removing values < 1.0 in frame 57
#  Removing values < 1.0 in frame 58
#  Removing values < 1.0 in frame 59
#  Removing values < 1.0 in frame 60
#  Removing values < 1.0 in frame 61
#  Removing values < 1.0 in frame 62
#  Removing values < 1.0 in frame 63
#  Removing values < 1.0 in frame 64
#  Removing values < 1.0 in frame 65
#  Removing values < 1.0 in frame 66
#  Removing values < 1.0 in frame 67
#  Removing values < 1.0 in frame 68
#  Removing values < 1.0 in frame 69
#  Removing values < 1.0 in frame 70
#  Removing values < 1.0 in frame 71
#  Removing values < 1.0 in frame 72
#  Removing values < 1.0 in frame 73
#  Removing values < 1.0 in frame 74
#  Removing values < 1.0 in frame 75
#  Removing values < 1.0 in frame 76
#  Removing values < 1.0 in frame 77
#  Removing values < 1.0 in frame 78
#  Removing values < 1.0 in frame 79
#  Removing values < 1.0 in frame 80
#  Removing values < 1.0 in frame 81
#  Removing values < 1.0 in frame 82
#  Removing values < 1.0 in frame 83
#  Removing values < 1.0 in frame 84
#  Removing values < 1.0 in frame 85
#  Removing values < 1.0 in frame 86
#  Removing values < 1.0 in frame 87
#  Removing values < 1.0 in frame 88
#  Removing values < 1.0 in frame 89
#  Removing values < 1.0 in frame 90
#  Removing values < 1.0 in frame 91
#  Removing values < 1.0 in frame 92
#  Removing values < 1.0 in frame 93
#  Removing values < 1.0 in frame 94
#  Removing values < 1.0 in frame 95
#  Removing values < 1.0 in frame 96
#  Removing values < 1.0 in frame 97
#  Removing values < 1.0 in frame 98
#  Removing values < 1.0 in frame 99
# Processing frame 100
#  Removing values < 1.0 in frame 100
#  Removing values < 1.0 in frame 101
#  Removing values < 1.0 in frame 102
#  Removing values < 1.0 in frame 103
#  Removing values < 1.0 in frame 104
#  Removing values < 1.0 in frame 105
#  Removing values < 1.0 in frame 106
#  Removing values < 1.0 in frame 107
#  Removing values < 1.0 in frame 108
#  Removing values < 1.0 in frame 109
#  Removing values < 1.0 in frame 110
#  Removing values < 1.0 in frame 111
#  Removing values < 1.0 in frame 112
#  Removing values < 1.0 in frame 113
#  Removing values < 1.0 in frame 114
#  Removing values < 1.0 in frame 115
#  Removing values < 1.0 in frame 116
#  Removing values < 1.0 in frame 117
#  Removing values < 1.0 in frame 118
#  Removing values < 1.0 in frame 119
#  Removing values < 1.0 in frame 120
#  Removing values < 1.0 in frame 121
#  Removing values < 1.0 in frame 122
#  Removing values < 1.0 in frame 123
#  Removing values < 1.0 in frame 124
#  Removing values < 1.0 in frame 125
#  Removing values < 1.0 in frame 126
#  Removing values < 1.0 in frame 127
#  Removing values < 1.0 in frame 128
#  Removing values < 1.0 in frame 129
#  Removing values < 1.0 in frame 130
#  Removing values < 1.0 in frame 131
#  Removing values < 1.0 in frame 132
#  Removing values < 1.0 in frame 133
#  Removing values < 1.0 in frame 134
#  Removing values < 1.0 in frame 135
#  Removing values < 1.0 in frame 136
#  Removing values < 1.0 in frame 137
#  Removing values < 1.0 in frame 138
#  Removing values < 1.0 in frame 139
#  Removing values < 1.0 in frame 140
#  Removing values < 1.0 in frame 141
#  Removing values < 1.0 in frame 142
#  Removing values < 1.0 in frame 143
#  Removing values < 1.0 in frame 144
#  Removing values < 1.0 in frame 145
#  Removing values < 1.0 in frame 146
#  Removing values < 1.0 in frame 147
#  Removing values < 1.0 in frame 148
#  Removing values < 1.0 in frame 149
# Processing frame 150
#  Removing values < 1.0 in frame 150
#  Removing values < 1.0 in frame 151
#  Removing values < 1.0 in frame 152
#  Removing values < 1.0 in frame 153
#  Removing values < 1.0 in frame 154
#  Removing values < 1.0 in frame 155
#  Removing values < 1.0 in frame 156
#  Removing values < 1.0 in frame 157
#  Removing values < 1.0 in frame 158
#  Removing values < 1.0 in frame 159
#  Removing values < 1.0 in frame 160
#  Removing values < 1.0 in frame 161
#  Removing values < 1.0 in frame 162
#  Removing values < 1.0 in frame 163
#  Removing values < 1.0 in frame 164
#  Removing values < 1.0 in frame 165
#  Removing values < 1.0 in frame 166
#  Removing values < 1.0 in frame 167
#  Removing values < 1.0 in frame 168
#  Removing values < 1.0 in frame 169
#  Removing values < 1.0 in frame 170
#  Removing values < 1.0 in frame 171
#  Removing values < 1.0 in frame 172
#  Removing values < 1.0 in frame 173
#  Removing values < 1.0 in frame 174
#  Removing values < 1.0 in frame 175
#  Removing values < 1.0 in frame 176
#  Removing values < 1.0 in frame 177
#  Removing values < 1.0 in frame 178
#  Removing values < 1.0 in frame 179
#  Removing values < 1.0 in frame 180
#  Removing values < 1.0 in frame 181
#  Removing values < 1.0 in frame 182
#  Removing values < 1.0 in frame 183
#  Removing values < 1.0 in frame 184
#  Removing values < 1.0 in frame 185
#  Removing values < 1.0 in frame 186
#  Removing values < 1.0 in frame 187
#  Removing values < 1.0 in frame 188
#  Removing values < 1.0 in frame 189
#  Removing values < 1.0 in frame 190
#  Removing values < 1.0 in frame 191
#  Removing values < 1.0 in frame 192
#  Removing values < 1.0 in frame 193
#  Removing values < 1.0 in frame 194
#  Removing values < 1.0 in frame 195
#  Removing values < 1.0 in frame 196
#  Removing values < 1.0 in frame 197
#  Removing values < 1.0 in frame 198
#  Removing values < 1.0 in frame 199
# Processing frame 200
#  Removing values < 1.0 in frame 200

# %% [markdown]
# Note: If you have linear drift in X/Y during PSF measurement you can correct for it at this stage using the `driftx` and `drifty` arguments to `psfZStack()`. One way to estimate the correct values to use is to analyze the entire calibration movie, then use `multi_plane.zstack_xydrift.xyDrift()`.

# %% [markdown]
# ### Measure the PSFs for each channel.
#
# If you are doing multicolor analysis at the same time then you'll want to use `normalize = True`. In multicolor analysis each camera would also be detecting different light wavelengths.
#
# As with `Spliner` PSF measurement, you will need a text file containing the z-offset of each frame in the movie. This file contains two columns, the first is whether or not the data in this frame should be used (0 = No, 1 = Yes) and the second contains the z offset in microns. In this example this was automatically generated by the `makeSampleData()` function.

# %%
# Load sample z_offsets.txt file. In this example every frame is valid.
import numpy
z_offsets = numpy.loadtxt("z_offset.txt")

print(z_offsets[:,:])
# Out:
# [[ 1.0000000e+00 -1.0000000e+00]
#  [ 1.0000000e+00 -9.9000000e-01]
#  [ 1.0000000e+00 -9.8000000e-01]
#  [ 1.0000000e+00 -9.7000000e-01]
#  [ 1.0000000e+00 -9.6000000e-01]
#  [ 1.0000000e+00 -9.5000000e-01]
#  [ 1.0000000e+00 -9.4000000e-01]
#  [ 1.0000000e+00 -9.3000000e-01]
#  [ 1.0000000e+00 -9.2000000e-01]
#  [ 1.0000000e+00 -9.1000000e-01]
#  [ 1.0000000e+00 -9.0000000e-01]
#  [ 1.0000000e+00 -8.9000000e-01]
#  [ 1.0000000e+00 -8.8000000e-01]
#  [ 1.0000000e+00 -8.7000000e-01]
#  [ 1.0000000e+00 -8.6000000e-01]
#  [ 1.0000000e+00 -8.5000000e-01]
#  [ 1.0000000e+00 -8.4000000e-01]
#  [ 1.0000000e+00 -8.3000000e-01]
#  [ 1.0000000e+00 -8.2000000e-01]
#  [ 1.0000000e+00 -8.1000000e-01]
#  [ 1.0000000e+00 -8.0000000e-01]
#  [ 1.0000000e+00 -7.9000000e-01]
#  [ 1.0000000e+00 -7.8000000e-01]
#  [ 1.0000000e+00 -7.7000000e-01]
#  [ 1.0000000e+00 -7.6000000e-01]
#  [ 1.0000000e+00 -7.5000000e-01]
#  [ 1.0000000e+00 -7.4000000e-01]
#  [ 1.0000000e+00 -7.3000000e-01]
#  [ 1.0000000e+00 -7.2000000e-01]
#  [ 1.0000000e+00 -7.1000000e-01]
#  [ 1.0000000e+00 -7.0000000e-01]
#  [ 1.0000000e+00 -6.9000000e-01]
#  [ 1.0000000e+00 -6.8000000e-01]
#  [ 1.0000000e+00 -6.7000000e-01]
#  [ 1.0000000e+00 -6.6000000e-01]
#  [ 1.0000000e+00 -6.5000000e-01]
#  [ 1.0000000e+00 -6.4000000e-01]
#  [ 1.0000000e+00 -6.3000000e-01]
#  [ 1.0000000e+00 -6.2000000e-01]
#  [ 1.0000000e+00 -6.1000000e-01]
#  [ 1.0000000e+00 -6.0000000e-01]
#  [ 1.0000000e+00 -5.9000000e-01]
#  [ 1.0000000e+00 -5.8000000e-01]
#  [ 1.0000000e+00 -5.7000000e-01]
#  [ 1.0000000e+00 -5.6000000e-01]
#  [ 1.0000000e+00 -5.5000000e-01]
#  [ 1.0000000e+00 -5.4000000e-01]
#  [ 1.0000000e+00 -5.3000000e-01]
#  [ 1.0000000e+00 -5.2000000e-01]
#  [ 1.0000000e+00 -5.1000000e-01]
#  [ 1.0000000e+00 -5.0000000e-01]
#  [ 1.0000000e+00 -4.9000000e-01]
#  [ 1.0000000e+00 -4.8000000e-01]
#  [ 1.0000000e+00 -4.7000000e-01]
#  [ 1.0000000e+00 -4.6000000e-01]
#  [ 1.0000000e+00 -4.5000000e-01]
#  [ 1.0000000e+00 -4.4000000e-01]
#  [ 1.0000000e+00 -4.3000000e-01]
#  [ 1.0000000e+00 -4.2000000e-01]
#  [ 1.0000000e+00 -4.1000000e-01]
#  [ 1.0000000e+00 -4.0000000e-01]
#  [ 1.0000000e+00 -3.9000000e-01]
#  [ 1.0000000e+00 -3.8000000e-01]
#  [ 1.0000000e+00 -3.7000000e-01]
#  [ 1.0000000e+00 -3.6000000e-01]
#  [ 1.0000000e+00 -3.5000000e-01]
#  [ 1.0000000e+00 -3.4000000e-01]
#  [ 1.0000000e+00 -3.3000000e-01]
#  [ 1.0000000e+00 -3.2000000e-01]
#  [ 1.0000000e+00 -3.1000000e-01]
#  [ 1.0000000e+00 -3.0000000e-01]
#  [ 1.0000000e+00 -2.9000000e-01]
#  [ 1.0000000e+00 -2.8000000e-01]
#  [ 1.0000000e+00 -2.7000000e-01]
#  [ 1.0000000e+00 -2.6000000e-01]
#  [ 1.0000000e+00 -2.5000000e-01]
#  [ 1.0000000e+00 -2.4000000e-01]
#  [ 1.0000000e+00 -2.3000000e-01]
#  [ 1.0000000e+00 -2.2000000e-01]
#  [ 1.0000000e+00 -2.1000000e-01]
#  [ 1.0000000e+00 -2.0000000e-01]
#  [ 1.0000000e+00 -1.9000000e-01]
#  [ 1.0000000e+00 -1.8000000e-01]
#  [ 1.0000000e+00 -1.7000000e-01]
#  [ 1.0000000e+00 -1.6000000e-01]
#  [ 1.0000000e+00 -1.5000000e-01]
#  [ 1.0000000e+00 -1.4000000e-01]
#  [ 1.0000000e+00 -1.3000000e-01]
#  [ 1.0000000e+00 -1.2000000e-01]
#  [ 1.0000000e+00 -1.1000000e-01]
#  [ 1.0000000e+00 -1.0000000e-01]
#  [ 1.0000000e+00 -9.0000000e-02]
#  [ 1.0000000e+00 -8.0000000e-02]
#  [ 1.0000000e+00 -7.0000000e-02]
#  [ 1.0000000e+00 -6.0000000e-02]
#  [ 1.0000000e+00 -5.0000000e-02]
#  [ 1.0000000e+00 -4.0000000e-02]
#  [ 1.0000000e+00 -3.0000000e-02]
#  [ 1.0000000e+00 -2.0000000e-02]
#  [ 1.0000000e+00 -1.0000000e-02]
#  [ 1.0000000e+00  8.8817842e-16]
#  [ 1.0000000e+00  1.0000000e-02]
#  [ 1.0000000e+00  2.0000000e-02]
#  [ 1.0000000e+00  3.0000000e-02]
#  [ 1.0000000e+00  4.0000000e-02]
#  [ 1.0000000e+00  5.0000000e-02]
#  [ 1.0000000e+00  6.0000000e-02]
#  [ 1.0000000e+00  7.0000000e-02]
#  [ 1.0000000e+00  8.0000000e-02]
#  [ 1.0000000e+00  9.0000000e-02]
#  [ 1.0000000e+00  1.0000000e-01]
#  [ 1.0000000e+00  1.1000000e-01]
#  [ 1.0000000e+00  1.2000000e-01]
#  [ 1.0000000e+00  1.3000000e-01]
#  [ 1.0000000e+00  1.4000000e-01]
#  [ 1.0000000e+00  1.5000000e-01]
#  [ 1.0000000e+00  1.6000000e-01]
#  [ 1.0000000e+00  1.7000000e-01]
#  [ 1.0000000e+00  1.8000000e-01]
#  [ 1.0000000e+00  1.9000000e-01]
#  [ 1.0000000e+00  2.0000000e-01]
#  [ 1.0000000e+00  2.1000000e-01]
#  [ 1.0000000e+00  2.2000000e-01]
#  [ 1.0000000e+00  2.3000000e-01]
#  [ 1.0000000e+00  2.4000000e-01]
#  [ 1.0000000e+00  2.5000000e-01]
#  [ 1.0000000e+00  2.6000000e-01]
#  [ 1.0000000e+00  2.7000000e-01]
#  [ 1.0000000e+00  2.8000000e-01]
#  [ 1.0000000e+00  2.9000000e-01]
#  [ 1.0000000e+00  3.0000000e-01]
#  [ 1.0000000e+00  3.1000000e-01]
#  [ 1.0000000e+00  3.2000000e-01]
#  [ 1.0000000e+00  3.3000000e-01]
#  [ 1.0000000e+00  3.4000000e-01]
#  [ 1.0000000e+00  3.5000000e-01]
#  [ 1.0000000e+00  3.6000000e-01]
#  [ 1.0000000e+00  3.7000000e-01]
#  [ 1.0000000e+00  3.8000000e-01]
#  [ 1.0000000e+00  3.9000000e-01]
#  [ 1.0000000e+00  4.0000000e-01]
#  [ 1.0000000e+00  4.1000000e-01]
#  [ 1.0000000e+00  4.2000000e-01]
#  [ 1.0000000e+00  4.3000000e-01]
#  [ 1.0000000e+00  4.4000000e-01]
#  [ 1.0000000e+00  4.5000000e-01]
#  [ 1.0000000e+00  4.6000000e-01]
#  [ 1.0000000e+00  4.7000000e-01]
#  [ 1.0000000e+00  4.8000000e-01]
#  [ 1.0000000e+00  4.9000000e-01]
#  [ 1.0000000e+00  5.0000000e-01]
#  [ 1.0000000e+00  5.1000000e-01]
#  [ 1.0000000e+00  5.2000000e-01]
#  [ 1.0000000e+00  5.3000000e-01]
#  [ 1.0000000e+00  5.4000000e-01]
#  [ 1.0000000e+00  5.5000000e-01]
#  [ 1.0000000e+00  5.6000000e-01]
#  [ 1.0000000e+00  5.7000000e-01]
#  [ 1.0000000e+00  5.8000000e-01]
#  [ 1.0000000e+00  5.9000000e-01]
#  [ 1.0000000e+00  6.0000000e-01]
#  [ 1.0000000e+00  6.1000000e-01]
#  [ 1.0000000e+00  6.2000000e-01]
#  [ 1.0000000e+00  6.3000000e-01]
#  [ 1.0000000e+00  6.4000000e-01]
#  [ 1.0000000e+00  6.5000000e-01]
#  [ 1.0000000e+00  6.6000000e-01]
#  [ 1.0000000e+00  6.7000000e-01]
#  [ 1.0000000e+00  6.8000000e-01]
#  [ 1.0000000e+00  6.9000000e-01]
#  [ 1.0000000e+00  7.0000000e-01]
#  [ 1.0000000e+00  7.1000000e-01]
#  [ 1.0000000e+00  7.2000000e-01]
#  [ 1.0000000e+00  7.3000000e-01]
#  [ 1.0000000e+00  7.4000000e-01]
#  [ 1.0000000e+00  7.5000000e-01]
#  [ 1.0000000e+00  7.6000000e-01]
#  [ 1.0000000e+00  7.7000000e-01]
#  [ 1.0000000e+00  7.8000000e-01]
#  [ 1.0000000e+00  7.9000000e-01]
#  [ 1.0000000e+00  8.0000000e-01]
#  [ 1.0000000e+00  8.1000000e-01]
#  [ 1.0000000e+00  8.2000000e-01]
#  [ 1.0000000e+00  8.3000000e-01]
#  [ 1.0000000e+00  8.4000000e-01]
#  [ 1.0000000e+00  8.5000000e-01]
#  [ 1.0000000e+00  8.6000000e-01]
#  [ 1.0000000e+00  8.7000000e-01]
#  [ 1.0000000e+00  8.8000000e-01]
#  [ 1.0000000e+00  8.9000000e-01]
#  [ 1.0000000e+00  9.0000000e-01]
#  [ 1.0000000e+00  9.1000000e-01]
#  [ 1.0000000e+00  9.2000000e-01]
#  [ 1.0000000e+00  9.3000000e-01]
#  [ 1.0000000e+00  9.4000000e-01]
#  [ 1.0000000e+00  9.5000000e-01]
#  [ 1.0000000e+00  9.6000000e-01]
#  [ 1.0000000e+00  9.7000000e-01]
#  [ 1.0000000e+00  9.8000000e-01]
#  [ 1.0000000e+00  9.9000000e-01]
#  [ 1.0000000e+00  1.0000000e+00]]

# %%
# PSF measurement
import storm_analysis.multi_plane.measure_psf as measurePSF

print("{0:.3f} pixel size (nm)".format(multiplane_measure_psf.pixel_size))
print("{0:.3f} spline z range (um)".format(multiplane_measure_psf.spline_z_range))
print()

measurePSF.measurePSF("c1_zstack.npy", 
                      "z_offset.txt", 
                      "c1_psf.psf", 
                      pixel_size = multiplane_measure_psf.pixel_size * 1.0e-3, # Pixel size is in microns.
                      refine = False, 
                      z_range = multiplane_measure_psf.spline_z_range, # Spline z range in microns. 
                      z_step = 0.050, 
                      normalize = False)

print()
measurePSF.measurePSF("c2_zstack.npy", 
                      "z_offset.txt", 
                      "c2_psf.psf", 
                      pixel_size = multiplane_measure_psf.pixel_size * 1.0e-3, # Pixel size is in microns.
                      refine = False, 
                      z_range = multiplane_measure_psf.spline_z_range, # Spline z range in microns. 
                      z_step = 0.050, 
                      normalize = False)
# Out:
# 100.000 pixel size (nm)
# 1.000 spline z range (um)
#
# z plane 0 has 3 samples
# z plane 1 has 5 samples
# z plane 2 has 5 samples
# z plane 3 has 5 samples
# z plane 4 has 5 samples
# z plane 5 has 5 samples
# z plane 6 has 5 samples
# z plane 7 has 5 samples
# z plane 8 has 5 samples
# z plane 9 has 5 samples
# z plane 10 has 5 samples
# z plane 11 has 5 samples
# z plane 12 has 5 samples
# z plane 13 has 5 samples
# z plane 14 has 5 samples
# z plane 15 has 5 samples
# z plane 16 has 5 samples
# z plane 17 has 5 samples
# z plane 18 has 5 samples
# z plane 19 has 5 samples
# z plane 20 has 5 samples
# z plane 21 has 5 samples
# z plane 22 has 5 samples
# z plane 23 has 5 samples
# z plane 24 has 5 samples
# z plane 25 has 5 samples
# z plane 26 has 5 samples
# z plane 27 has 5 samples
# z plane 28 has 5 samples
# z plane 29 has 5 samples
# z plane 30 has 5 samples
# z plane 31 has 5 samples
# z plane 32 has 5 samples
# z plane 33 has 5 samples
# z plane 34 has 5 samples
# z plane 35 has 5 samples
# z plane 36 has 5 samples
# z plane 37 has 5 samples
# z plane 38 has 5 samples
# z plane 39 has 5 samples
# z plane 40 has 3 samples
#
# z plane 0 has 3 samples
# z plane 1 has 5 samples
# z plane 2 has 5 samples
# z plane 3 has 5 samples
# z plane 4 has 5 samples
# z plane 5 has 5 samples
# z plane 6 has 5 samples
# z plane 7 has 5 samples
# z plane 8 has 5 samples
# z plane 9 has 5 samples
# z plane 10 has 5 samples
# z plane 11 has 5 samples
# z plane 12 has 5 samples
# z plane 13 has 5 samples
# z plane 14 has 5 samples
# z plane 15 has 5 samples
# z plane 16 has 5 samples
# z plane 17 has 5 samples
# z plane 18 has 5 samples
# z plane 19 has 5 samples
# z plane 20 has 5 samples
# z plane 21 has 5 samples
# z plane 22 has 5 samples
# z plane 23 has 5 samples
# z plane 24 has 5 samples
# z plane 25 has 5 samples
# z plane 26 has 5 samples
# z plane 27 has 5 samples
# z plane 28 has 5 samples
# z plane 29 has 5 samples
# z plane 30 has 5 samples
# z plane 31 has 5 samples
# z plane 32 has 5 samples
# z plane 33 has 5 samples
# z plane 34 has 5 samples
# z plane 35 has 5 samples
# z plane 36 has 5 samples
# z plane 37 has 5 samples
# z plane 38 has 5 samples
# z plane 39 has 5 samples
# z plane 40 has 3 samples

# %%
multiplane_measure_psf.spline_z_range
# Out:
# 1.0

# %% [markdown]
# ### Visualize the measured PSFs

# %%
import storm_analysis.jupyter_examples.psf_images as psfImages

psfImages.psfImages("c1_psf.psf")
psfImages.psfImages("c2_psf.psf")
# Out:
# PSF shape: (41, 24, 24)
# pixel size: 0.100um
# zmin, zmax: -1000.0nm, 1000.0nm
# Plots are in microns
# PSF shape: (41, 24, 24)
# pixel size: 0.100um
# zmin, zmax: -1000.0nm, 1000.0nm
# Plots are in microns

# %% [markdown]
# The next step is to convert the measured PSFs to splines. This is discussed in the `multiplane_psfs_to_splines` notebook.
#
# You can also examine the PSFs with a tool like ImageJ. Tiff versions of the PSFs are also created, "c1_psf.tif" and "c2_psf.tif" in this example.
